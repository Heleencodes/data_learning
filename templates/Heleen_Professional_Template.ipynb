# %%
from heleen_startup import start
start()

# %%
from datetime import datetime

print("📘 Heleen Professional Notebook")
print("Created:", datetime.now().strftime("%Y-%m-%d %H:%M"))
print("Project Path:", !pwd)

# %%
# Load your dataset(s) here
# df = pd.read_csv("path/to/file.csv")
# df_info(df)

# %%
# Analysis / Prep / Explore
# Your analysis code goes here

# %%
# Model / Visualizations / Results

# %%
# Save results
# df.to_csv("results/output.csv", index=False)

# %%
# Optional: force tools folder into sys.path
import sys, pathlib
tools_path = pathlib.Path.cwd().parent / "tools"
if tools_path.exists():
    sys.path.append(str(tools_path))
    print("✔ tools path added:", tools_path)
